# %% [markdown]
# https://github.com/ehfahad/Comparative-Analysis-of-RNNs-in-Stock-Price-Prediction

# %%
#Impor Library
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib. pyplot as plt
import matplotlib
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import LSTM,SimpleRNN,GRU,Dense,Dropout
from sklearn.model_selection import TimeSeriesSplit
import matplotlib. dates as mandates
from sklearn import linear_model
from keras.models import Sequential
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras import optimizers
from tensorflow.keras.optimizers import SGD, Adam, RMSprop 
from keras.models import load_model
from keras.utils.vis_utils import plot_model
import timeit
from sklearn.metrics import make_scorer, r2_score, confusion_matrix, mean_squared_error
from sklearn import metrics
from math import sqrt

# Tampilan layar
pd.set_option('display.max_rows', 800)
pd.set_option('display.max_columns', 500)

# %%
#Ambil Data
df = pd.read_csv("orcl.csv",index_col='Date',parse_dates=True,infer_datetime_format=True)
df.to_pickle('dataset.pkl')   
df = pd.read_pickle('dataset.pkl') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5044 entries, 2000-06-30 to 2020-07-20
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       5044 non-null   float64
#  1   High       5044 non-null   float64
#  2   Low        5044 non-null   float64
#  3   Close      5044 non-null   float64
#  4   Adj Close  5044 non-null   float64
#  5   Volume     5044 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 275.8 KB

# %%
agg_dict = {'Open': 'first',
          'High': 'max',
          'Low': 'min',
          'Close': 'last',
          'Adj Close': 'last',
          'Volume': 'mean'}

# resampled dataframe
# 'W' means weekly aggregation
df = df.resample('5D').agg(agg_dict)

# %%
df.tail()
# Out:
#                  Open       High        Low      Close  Adj Close  \
# Date
# 2020-06-30  54.799999  56.430000  54.500000  55.939999  55.704502
# 2020-07-05  56.200001  57.799999  55.990002  57.529999  57.287807
# 2020-07-10  57.470001  57.840000  56.480000  57.200001  57.200001
# 2020-07-15  57.419998  57.840000  54.759998  54.900002  54.900002
# 2020-07-20  54.880001  55.514999  54.695000  55.450001  55.450001
#
#                   Volume
# Date
# 2020-06-30  1.740720e+07
# 2020-07-05  1.420415e+07
# 2020-07-10  1.469723e+07
# 2020-07-15  1.123163e+07
# 2020-07-20  9.410108e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1466 entries, 2000-06-30 to 2020-07-20
# Freq: 5D
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1466 non-null   float64
#  1   High       1466 non-null   float64
#  2   Low        1466 non-null   float64
#  3   Close      1466 non-null   float64
#  4   Adj Close  1466 non-null   float64
#  5   Volume     1466 non-null   float64
# dtypes: float64(6)
# memory usage: 120.2 KB

# %%
#Print the shape of Dataframe  and Check for Null Values
print("Dataframe Shape: ", df. shape)
print("Null Value Present: ", df.isnull().values.any())
# Out:
# Dataframe Shape:  (1466, 6)
# Null Value Present:  False

# %%
#Plot the True Adj Close Value
df["Close"].plot()

# %%
#Set Target Variable
output_var = pd.DataFrame(df['Close'])
#Selecting the Features
features = ['Open', 'High', 'Low', 'Volume']

# %%
#Scaling
scaler = StandardScaler()# standar scaler lebih baik
#scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=df.index)
feature_transform.head()
# Out:
#                 Open      High       Low    Volume
# Date
# 2000-06-30  0.824371  0.914391  0.824959  0.569240
# 2000-07-05  0.696241  0.669944  0.565994  1.664611
# 2000-07-10  0.617564  0.634388  0.543277  0.490002
# 2000-07-15  0.642291  0.683278  0.611426  0.055063
# 2000-07-20  0.624308  0.718833  0.675032  0.258420

# %%
#Splitting to Training set and Test set
timesplit= TimeSeriesSplit(n_splits=10)
for train_index, test_index in timesplit.split(feature_transform):
        X_train, X_test = feature_transform[:len(train_index)], feature_transform[len(train_index): (len(train_index)+len(test_index))]
        y_train, y_test = output_var[:len(train_index)].values.ravel(), output_var[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %%
#Process the data for LSTM
trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
#Rencana Model

jml_epochs= 100
input_optimasi = 'SGD'
input_lr = '001'

#Set optimizer
if input_lr == '01':
  lr=0.1
elif input_lr == '001':
  lr=0.01
elif input_lr == '0001':
  lr=0.001

if input_optimasi == 'SGD':
  opt = SGD(learning_rate=lr)
elif input_optimasi == 'Adam':
  opt = Adam(learning_rate=lr)
elif input_optimasi == 'RMSprop':
  opt = RMSprop(learning_rate=lr)


model = Sequential()
model.add(LSTM(32, input_dim=len(features), activation='relu', kernel_initializer='he_normal'))
#model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mae','mse'])




model.summary()
#plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                4736
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 4,769
# Trainable params: 4,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Model Training

start = timeit.default_timer()
history=model.fit(X_train, y_train, epochs=jml_epochs, batch_size=16, verbose=1, shuffle=False)
stop = timeit.default_timer()
# Out:
# Epoch 1/100
# 84/84 [==============================] - 2s 6ms/step - loss: 216.3783 - mae: 9.6670 - mse: 216.3783
# Epoch 2/100
# 84/84 [==============================] - 1s 6ms/step - loss: 150.5959 - mae: 6.2368 - mse: 150.5959
# Epoch 3/100
# 84/84 [==============================] - 0s 6ms/step - loss: 54.6386 - mae: 3.4143 - mse: 54.6386
# Epoch 4/100
# 84/84 [==============================] - 1s 6ms/step - loss: 16.5471 - mae: 2.0641 - mse: 16.5471
# Epoch 5/100
# 84/84 [==============================] - 0s 6ms/step - loss: 5.1141 - mae: 1.1939 - mse: 5.1141
# Epoch 6/100
# 84/84 [==============================] - 0s 6ms/step - loss: 7.1942 - mae: 1.2282 - mse: 7.1942
# Epoch 7/100
# 84/84 [==============================] - 0s 6ms/step - loss: 6.5004 - mae: 1.1478 - mse: 6.5004
# Epoch 8/100
# 84/84 [==============================] - 0s 6ms/step - loss: 6.3024 - mae: 1.1527 - mse: 6.3024
# Epoch 9/100
# 84/84 [==============================] - 0s 6ms/step - loss: 5.9471 - mae: 1.0975 - mse: 5.9471
# Epoch 10/100
# 84/84 [==============================] - 0s 6ms/step - loss: 5.7137 - mae: 1.0763 - mse: 5.7137
# Epoch 11/100
# 84/84 [==============================] - 0s 6ms/step - loss: 5.4324 - mae: 1.0456 - mse: 5.4324
# Epoch 12/100
# 84/84 [==============================] - 0s 6ms/step - loss: 5.2125 - mae: 1.0231 - mse: 5.2125
# Epoch 13/100
# 84/84 [==============================] - 0s 6ms/step - loss: 5.0160 - mae: 1.0024 - mse: 5.0160
# Epoch 14/100
# 84/84 [==============================] - 1s 6ms/step - loss: 4.8231 - mae: 0.9833 - mse: 4.8231
# Epoch 15/100
# 84/84 [==============================] - 0s 6ms/step - loss: 4.6531 - mae: 0.9667 - mse: 4.6531
# Epoch 16/100
# 84/84 [==============================] - 0s 6ms/step - loss: 4.4809 - mae: 0.9501 - mse: 4.4809
# Epoch 17/100
# 84/84 [==============================] - 0s 6ms/step - loss: 4.3064 - mae: 0.9341 - mse: 4.3064
# Epoch 18/100
# 84/84 [==============================] - 0s 6ms/step - loss: 4.1492 - mae: 0.9201 - mse: 4.1492
# Epoch 19/100
# 84/84 [==============================] - 0s 6ms/step - loss: 3.9876 - mae: 0.9059 - mse: 3.9876
# Epoch 20/100
# 84/84 [==============================] - 0s 6ms/step - loss: 3.8243 - mae: 0.8921 - mse: 3.8243
# Epoch 21/100
# 84/84 [==============================] - 0s 6ms/step - loss: 3.6675 - mae: 0.8794 - mse: 3.6675
# Epoch 22/100
# 84/84 [==============================] - 0s 6ms/step - loss: 3.5160 - mae: 0.8673 - mse: 3.5160
# Epoch 23/100
# 84/84 [==============================] - 0s 6ms/step - loss: 3.3877 - mae: 0.8572 - mse: 3.3877
# Epoch 24/100
# 84/84 [==============================] - 0s 6ms/step - loss: 3.2508 - mae: 0.8458 - mse: 3.2508
# Epoch 25/100
# 84/84 [==============================] - 0s 6ms/step - loss: 3.1195 - mae: 0.8352 - mse: 3.1195
# Epoch 26/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.9954 - mae: 0.8249 - mse: 2.9954
# Epoch 27/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.8756 - mae: 0.8148 - mse: 2.8756
# Epoch 28/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.7617 - mae: 0.8052 - mse: 2.7617
# Epoch 29/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.6528 - mae: 0.7955 - mse: 2.6528
# Epoch 30/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.5456 - mae: 0.7857 - mse: 2.5456
# Epoch 31/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.4437 - mae: 0.7763 - mse: 2.4437
# Epoch 32/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.3468 - mae: 0.7671 - mse: 2.3468
# Epoch 33/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.2545 - mae: 0.7581 - mse: 2.2545
# Epoch 34/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.1660 - mae: 0.7490 - mse: 2.1660
# Epoch 35/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.0813 - mae: 0.7400 - mse: 2.0813
# Epoch 36/100
# 84/84 [==============================] - 0s 6ms/step - loss: 2.0024 - mae: 0.7316 - mse: 2.0024
# Epoch 37/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.9283 - mae: 0.7232 - mse: 1.9283
# Epoch 38/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.8596 - mae: 0.7153 - mse: 1.8596
# Epoch 39/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.7950 - mae: 0.7077 - mse: 1.7950
# Epoch 40/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.7348 - mae: 0.7003 - mse: 1.7348
# Epoch 41/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.6780 - mae: 0.6931 - mse: 1.6780
# Epoch 42/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.6260 - mae: 0.6864 - mse: 1.6260
# Epoch 43/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.5766 - mae: 0.6798 - mse: 1.5766
# Epoch 44/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.5299 - mae: 0.6734 - mse: 1.5299
# Epoch 45/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.4855 - mae: 0.6671 - mse: 1.4855
# Epoch 46/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.4431 - mae: 0.6611 - mse: 1.4431
# Epoch 47/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.4037 - mae: 0.6553 - mse: 1.4037
# Epoch 48/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.3646 - mae: 0.6494 - mse: 1.3646
# Epoch 49/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.3272 - mae: 0.6438 - mse: 1.3272
# Epoch 50/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.2925 - mae: 0.6383 - mse: 1.2925
# Epoch 51/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.2570 - mae: 0.6325 - mse: 1.2570
# Epoch 52/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.2233 - mae: 0.6269 - mse: 1.2233
# Epoch 53/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.1909 - mae: 0.6213 - mse: 1.1909
# Epoch 54/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.1590 - mae: 0.6159 - mse: 1.1590
# Epoch 55/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.1300 - mae: 0.6107 - mse: 1.1300
# Epoch 56/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.1022 - mae: 0.6056 - mse: 1.1022
# Epoch 57/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.0759 - mae: 0.6007 - mse: 1.0759
# Epoch 58/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.0498 - mae: 0.5958 - mse: 1.0498
# Epoch 59/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.0257 - mae: 0.5911 - mse: 1.0257
# Epoch 60/100
# 84/84 [==============================] - 0s 6ms/step - loss: 1.0026 - mae: 0.5867 - mse: 1.0026
# Epoch 61/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.9804 - mae: 0.5823 - mse: 0.9804
# Epoch 62/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.9595 - mae: 0.5782 - mse: 0.9595
# Epoch 63/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.9390 - mae: 0.5740 - mse: 0.9390
# Epoch 64/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.9194 - mae: 0.5699 - mse: 0.9194
# Epoch 65/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.9007 - mae: 0.5659 - mse: 0.9007
# Epoch 66/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.8831 - mae: 0.5621 - mse: 0.8831
# Epoch 67/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.8664 - mae: 0.5585 - mse: 0.8664
# Epoch 68/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.8502 - mae: 0.5549 - mse: 0.8502
# Epoch 69/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.8345 - mae: 0.5514 - mse: 0.8345
# Epoch 70/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.8194 - mae: 0.5480 - mse: 0.8194
# Epoch 71/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.8050 - mae: 0.5448 - mse: 0.8050
# Epoch 72/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.7908 - mae: 0.5416 - mse: 0.7908
# Epoch 73/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.7773 - mae: 0.5385 - mse: 0.7773
# Epoch 74/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.7644 - mae: 0.5355 - mse: 0.7644
# Epoch 75/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.7518 - mae: 0.5326 - mse: 0.7518
# Epoch 76/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.7395 - mae: 0.5298 - mse: 0.7395
# Epoch 77/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.7290 - mae: 0.5272 - mse: 0.7290
# Epoch 78/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.7174 - mae: 0.5246 - mse: 0.7174
# Epoch 79/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.7074 - mae: 0.5221 - mse: 0.7074
# Epoch 80/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6965 - mae: 0.5194 - mse: 0.6965
# Epoch 81/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6874 - mae: 0.5172 - mse: 0.6874
# Epoch 82/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6773 - mae: 0.5148 - mse: 0.6773
# Epoch 83/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6685 - mae: 0.5125 - mse: 0.6685
# Epoch 84/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6602 - mae: 0.5104 - mse: 0.6602
# Epoch 85/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6510 - mae: 0.5081 - mse: 0.6510
# Epoch 86/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6432 - mae: 0.5061 - mse: 0.6432
# Epoch 87/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6356 - mae: 0.5041 - mse: 0.6356
# Epoch 88/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6283 - mae: 0.5021 - mse: 0.6283
# Epoch 89/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6192 - mae: 0.4999 - mse: 0.6192
# Epoch 90/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6128 - mae: 0.4982 - mse: 0.6128
# Epoch 91/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.6059 - mae: 0.4964 - mse: 0.6059
# Epoch 92/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.5991 - mae: 0.4946 - mse: 0.5991
# Epoch 93/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.5923 - mae: 0.4928 - mse: 0.5923
# Epoch 94/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.5858 - mae: 0.4911 - mse: 0.5858
# Epoch 95/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.5792 - mae: 0.4893 - mse: 0.5792
# Epoch 96/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.5729 - mae: 0.4876 - mse: 0.5729
# Epoch 97/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.5673 - mae: 0.4861 - mse: 0.5673
# Epoch 98/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.5619 - mae: 0.4845 - mse: 0.5619
# Epoch 99/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.5561 - mae: 0.4830 - mse: 0.5561
# Epoch 100/100
# 84/84 [==============================] - 0s 6ms/step - loss: 0.5510 - mae: 0.4815 - mse: 0.5510

# %%
#LSTM Prediction
y_pred= model.predict(X_test)

# %%
print ('R Squared =',r2_score(y_test, y_pred))
ORCL_R2_MODEL = r2_score(y_test, y_pred)

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
ORCL_MAE_MODEL = metrics.mean_absolute_error(y_test, y_pred)

print('Mean Absolute Percentage Error:', metrics.mean_absolute_percentage_error(y_test, y_pred))
ORCL_MAPE_MODEL = metrics.mean_absolute_percentage_error(y_test, y_pred)

print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
ORCL_RMSE_MODEL = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Out:
# R Squared = -1.1654140001673454
# Mean Absolute Error: 4.816386210792484
# Mean Absolute Percentage Error: 0.09066294615409101
# Root Mean Squared Error: 5.001008835143548

# %%
from prettytable import PrettyTable
waktu = stop - start
nmtabel = PrettyTable(["Model","Epoch","LR","OPT","R2","MAE","MAPE","RMSE","Waktu"])
nmtabel.add_row(["LSTM",jml_epochs,input_lr,input_optimasi,'{:.2f}'.format(ORCL_R2_MODEL), '{:.2f}'.format(ORCL_MAE_MODEL), '{:.2f}'.format(ORCL_MAPE_MODEL), '{:.2f}'.format(ORCL_RMSE_MODEL),'{:.0f}'.format(waktu)])
#nmtabel.add_row(["5","Paper Acuan","ORCL","LSTM","100","01","Adam","0.90153", "0.98621","1.97875","1.39695","-"])
print(nmtabel)
# Out:
# +-------+-------+-----+-----+-------+------+------+------+-------+
# | Model | Epoch |  LR | OPT |   R2  | MAE  | MAPE | RMSE | Waktu |
# +-------+-------+-----+-----+-------+------+------+------+-------+
# |  LSTM |  100  | 001 | SGD | -1.17 | 4.82 | 0.09 | 5.00 |   50  |
# +-------+-------+-----+-----+-------+------+------+------+-------+

# %%
#clear session
K.clear_session()
